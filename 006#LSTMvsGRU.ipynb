# %%
import pandas as pd

# %%
biGRU = pd.read_csv("./data/004#biGRU_diff.csv")

# %%
biLSTM = pd.read_csv("./data/004#dlstm_diff.csv")

# %%
biGRU
# Out:
#                                               urldata  pred  real  label
# 0   keyone=7976314481&keytwo=foo%2520AND%25201427%...     0     1      1
# 1   keyone=DF102861-F280-48A2-AAB8-8FD49E464E90&ke...     1     0      0
# 2   keyone=16-999.9+union+select+1%2Cconcat_ws%28u...     0     1      1
# 3   keyone=1478158744072_249&keytwo=1478073231783_...     0     1      1
# 4   keyone=-1+UNION+ALL+SELECT+1%2C2%2C3&keytwo=14...     0     1      1
# 5   keyone=-2551%2527%2520WHERE%25205598%253D5598%...     0     1      1
# 6   keyone=-1+union+select+1%2C2%2C3%2C4%2CUSER%28...     0     1      1
# 7   keyone=1478670190391_179&keytwo=1001-%5CN+unio...     0     1      1
# 8   keyone=dc11bc8986524b6adbce87e84a81c2558523238...     1     0      0
# 9   keyone=7971664867&keytwo=VdB25Ot2q&keythree=A+...     0     1      1
# 10  keyone=7977282134&keytwo=%25E5%25B7%25B2%25E7%...     1     0      0
# 11  keyone=-1%2F1%2F%252A%252A%2Funion%2523--&keyt...     0     1      1
# ...

# %%
biLSTM
# Out:
#                                               urldata  pred  real  label
# 0   keyone=7970626356&keytwo=652467c580e75e97717e8...     1     0      0
# 1   keyone=bhNcRw548oi0wGeAqZag&keytwo=6&keythree=...     1     0      0
# 2   keyone=mm_10024662_3445902_14412152%2502204.76...     1     0      0
# 3   keyone=7971664867&keytwo=VdB25Ot2q&keythree=A+...     0     1      1
# 4   keyone=don%27t+hate+%28%29+el+%28select%29+cri...     1     0      0
# 5   keyone=http%253A%252F%252Frdstat.tanx.com%252F...     1     0      0
# 6   keyone=1477407299127_296&keytwo=7982588470&key...     0     1      1
# 7   keyone=7874728191&keytwo=platform%253Dweb%2526...     1     0      0
# 8   keyone=http%253A%252F%252Frdstat.tanx.com%252F...     1     0      0
# 9   keyone=eae3eab34b8ee&keytwo=7315038849&keythre...     1     0      0
# 10  keyone=http%253A%2F%2Fmobile.163.com%2F16%2F11...     1     0      0
# 11  keyone=PEQCI1RyOWzqFt2FvHZIwL1VKS7IGdF0o6P%252...     1     0      0
# ...
